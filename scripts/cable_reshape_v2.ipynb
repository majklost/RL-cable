# %%
import os
import gymnasium as gym
from stable_baselines3 import PPO
from gymnasium.wrappers import TimeLimit
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize,VecMonitor
from stable_baselines3.common.env_util import make_vec_env
from deform_rl.envs.Cable_reshape_env.environment import CableReshapeV2,CableReshape
from stable_baselines3.common.utils import set_random_seed
from stable_baselines3.common.callbacks import EvalCallback,BaseCallback

import pygame

# %%
def make_env(rank,seed=0):
    """
    Utility function for multiprocessed env.

    :param env_id: (str) the environment ID
    :param seed: (int) the inital seed for RNG
    :param rank: (int) index of the subprocess
    """
    def _init():
        env = CableReshapeV2(render_mode='human',seg_num=10,cable_length=300,scale_factor=800)
        env = TimeLimit(env,max_episode_steps=1000)
        env = Monitor(env)
        # use a seed for reproducibility
        # Important: use a different seed for each environment
        # otherwise they would generate the same experiences
        env.reset(seed=seed + rank)
        return env

    set_random_seed(seed)
    return _init

env0 = DummyVecEnv([make_env(i+4) for i in range(4)])
training_env =VecNormalize(env0)
env1 = DummyVecEnv([make_env(i+4) for i in range(1)])
validation_env = VecNormalize(env1)

save_dir = os.path.join("saved_models/reshape")
log_dir = os.path.join("logs/reshape")
os.makedirs(save_dir, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)

class SaveNormalizeCallback(BaseCallback):
    def __init__(self, verbose = 0,):
        super().__init__(verbose)

    def _on_step(self):
        training_env.save(save_dir+"/vecnorms.pkl")
        super()._on_step()
        return True
save_callback = SaveNormalizeCallback()


eval_callback = EvalCallback(
    eval_env=validation_env,
    n_eval_episodes=15,
    eval_freq=10000,
    callback_on_new_best=save_callback,
    best_model_save_path=save_dir,
    verbose=1,
    render=False
)

# %%
model = PPO('MlpPolicy', training_env,device='cpu',verbose=1,tensorboard_log=log_dir)
model.learn(800000,tb_log_name='reshape_v2')
# Out:
# Using cpu device
# Logging to logs/reshape/reshape_v2_17
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | -4.71e+03 |
# | time/              |           |
# |    fps             | 2241      |
# |    iterations      | 1         |
# |    time_elapsed    | 3         |
# |    total_timesteps | 8192      |
# ----------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -4.99e+03   |
# | time/                   |             |
# |    fps                  | 1693        |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.016673803 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | 0.4161058   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00519    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0194     |
# |    std                  | 0.998       |
# |    value_loss           | 0.206       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.27e+03   |
# | time/                   |             |
# |    fps                  | 1598        |
# |    iterations           | 3           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.014803538 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.3       |
# |    explained_variance   | 0.8586021   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00595    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.014      |
# |    std                  | 0.996       |
# |    value_loss           | 0.0119      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.6e+03    |
# | time/                   |             |
# |    fps                  | 1509        |
# |    iterations           | 4           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.014902629 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | -0.27706265 |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0501     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.993       |
# |    value_loss           | 0.0118      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -6.36e+03    |
# | time/                   |              |
# |    fps                  | 1458         |
# |    iterations           | 5            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0150961215 |
# |    clip_fraction        | 0.187        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.2        |
# |    explained_variance   | 0.71636105   |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0169      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0145      |
# |    std                  | 0.993        |
# |    value_loss           | 0.0034       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.21e+03   |
# | time/                   |             |
# |    fps                  | 1429        |
# |    iterations           | 6           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.016010642 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0.87350833  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0318     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0158     |
# |    std                  | 0.993       |
# |    value_loss           | 0.0025      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.57e+03   |
# | time/                   |             |
# |    fps                  | 1428        |
# |    iterations           | 7           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.017495265 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0.7339251   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0124     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0164     |
# |    std                  | 0.993       |
# |    value_loss           | 0.00231     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.11e+03   |
# | time/                   |             |
# |    fps                  | 1426        |
# |    iterations           | 8           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.016686518 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0.8758309   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0355     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.992       |
# |    value_loss           | 0.00372     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.1e+03    |
# | time/                   |             |
# |    fps                  | 1419        |
# |    iterations           | 9           |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.017295003 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0.4317944   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0229     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 0.993       |
# |    value_loss           | 0.00391     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.1e+03    |
# | time/                   |             |
# |    fps                  | 1417        |
# |    iterations           | 10          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.017545652 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0.8950937   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0179     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.993       |
# |    value_loss           | 0.00128     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.05e+03   |
# | time/                   |             |
# |    fps                  | 1417        |
# |    iterations           | 11          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.017384153 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0.9146084   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00107    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.993       |
# |    value_loss           | 0.00153     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.86e+03   |
# | time/                   |             |
# |    fps                  | 1411        |
# |    iterations           | 12          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.017608084 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0.89828444  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0475     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.016      |
# |    std                  | 0.993       |
# |    value_loss           | 0.00104     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -7.84e+03  |
# | time/                   |            |
# |    fps                  | 1411       |
# |    iterations           | 13         |
# |    time_elapsed         | 75         |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.01694483 |
# |    clip_fraction        | 0.208      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.2      |
# |    explained_variance   | 0.85326993 |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.02      |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0169    |
# |    std                  | 0.994      |
# |    value_loss           | 0.00139    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.91e+03   |
# | time/                   |             |
# |    fps                  | 1402        |
# |    iterations           | 14          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.017827038 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0.80809057  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0379     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0155     |
# |    std                  | 0.993       |
# |    value_loss           | 0.0033      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.56e+03   |
# | time/                   |             |
# |    fps                  | 1390        |
# |    iterations           | 15          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.015955448 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0.92784214  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0415     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.992       |
# |    value_loss           | 0.000937    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -8.27e+03  |
# | time/                   |            |
# |    fps                  | 1388       |
# |    iterations           | 16         |
# |    time_elapsed         | 94         |
# |    total_timesteps      | 131072     |
# | train/                  |            |
# |    approx_kl            | 0.01625736 |
# |    clip_fraction        | 0.207      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.2      |
# |    explained_variance   | 0.8598349  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0263    |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0159    |
# |    std                  | 0.991      |
# |    value_loss           | 0.00155    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.24e+03   |
# | time/                   |             |
# |    fps                  | 1388        |
# |    iterations           | 17          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.020287044 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0.98133886  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0474     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0179     |
# |    std                  | 0.989       |
# |    value_loss           | 0.000712    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.34e+03   |
# | time/                   |             |
# |    fps                  | 1389        |
# |    iterations           | 18          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.017860208 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.88786256  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0577     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.989       |
# |    value_loss           | 0.00035     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.1e+03    |
# | time/                   |             |
# |    fps                  | 1385        |
# |    iterations           | 19          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.018180687 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.96533805  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0164     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0132     |
# |    std                  | 0.988       |
# |    value_loss           | 0.000378    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.73e+03   |
# | time/                   |             |
# |    fps                  | 1385        |
# |    iterations           | 20          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.019148577 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.89385027  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0419     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0154     |
# |    std                  | 0.986       |
# |    value_loss           | 0.000671    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.24e+03   |
# | time/                   |             |
# |    fps                  | 1387        |
# |    iterations           | 21          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.019643161 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.8846007   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0164     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0179     |
# |    std                  | 0.986       |
# |    value_loss           | 0.000494    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.2e+03    |
# | time/                   |             |
# |    fps                  | 1388        |
# |    iterations           | 22          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.018183805 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.77923846  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00733     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.988       |
# |    value_loss           | 0.00186     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.22e+03   |
# | time/                   |             |
# |    fps                  | 1389        |
# |    iterations           | 23          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.016227655 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.65947     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.039      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00941    |
# |    std                  | 0.987       |
# |    value_loss           | 0.000898    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.19e+03   |
# | time/                   |             |
# |    fps                  | 1386        |
# |    iterations           | 24          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.017839989 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.9278938   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00914    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0132     |
# |    std                  | 0.985       |
# |    value_loss           | 0.0007      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.2e+03    |
# | time/                   |             |
# |    fps                  | 1385        |
# |    iterations           | 25          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.015149726 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.8935496   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0237     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.989       |
# |    value_loss           | 0.00047     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.05e+03   |
# | time/                   |             |
# |    fps                  | 1385        |
# |    iterations           | 26          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.020179704 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.92492676  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0341     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0161     |
# |    std                  | 0.986       |
# |    value_loss           | 0.000464    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.3e+03    |
# | time/                   |             |
# |    fps                  | 1385        |
# |    iterations           | 27          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.017501801 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.92003024  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0479     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.988       |
# |    value_loss           | 0.00027     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -6.45e+03  |
# | time/                   |            |
# |    fps                  | 1382       |
# |    iterations           | 28         |
# |    time_elapsed         | 165        |
# |    total_timesteps      | 229376     |
# | train/                  |            |
# |    approx_kl            | 0.01737692 |
# |    clip_fraction        | 0.226      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.1      |
# |    explained_variance   | 0.9385932  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0124    |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.014     |
# |    std                  | 0.987      |
# |    value_loss           | 0.000323   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.42e+03   |
# | time/                   |             |
# |    fps                  | 1381        |
# |    iterations           | 29          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.016607346 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.7357985   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0554     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.985       |
# |    value_loss           | 0.000587    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -6.34e+03  |
# | time/                   |            |
# |    fps                  | 1377       |
# |    iterations           | 30         |
# |    time_elapsed         | 178        |
# |    total_timesteps      | 245760     |
# | train/                  |            |
# |    approx_kl            | 0.01802368 |
# |    clip_fraction        | 0.237      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28        |
# |    explained_variance   | 0.9536739  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0004     |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0145    |
# |    std                  | 0.984      |
# |    value_loss           | 0.000347   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.26e+03   |
# | time/                   |             |
# |    fps                  | 1362        |
# |    iterations           | 31          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.019663684 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.97960865  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00799    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0167     |
# |    std                  | 0.985       |
# |    value_loss           | 0.000349    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6e+03      |
# | time/                   |             |
# |    fps                  | 1327        |
# |    iterations           | 32          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.018123858 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.93872213  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0393     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 0.984       |
# |    value_loss           | 0.00023     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -5.76e+03  |
# | time/                   |            |
# |    fps                  | 1327       |
# |    iterations           | 33         |
# |    time_elapsed         | 203        |
# |    total_timesteps      | 270336     |
# | train/                  |            |
# |    approx_kl            | 0.01808355 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28        |
# |    explained_variance   | 0.8987696  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0363    |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0114    |
# |    std                  | 0.983      |
# |    value_loss           | 0.000209   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -5.49e+03   |
# | time/                   |             |
# |    fps                  | 1328        |
# |    iterations           | 34          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.016092032 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28         |
# |    explained_variance   | 0.9431988   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.02       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.983       |
# |    value_loss           | 0.000664    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -5.25e+03   |
# | time/                   |             |
# |    fps                  | 1328        |
# |    iterations           | 35          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.019600563 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28         |
# |    explained_variance   | 0.8378134   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0132     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.982       |
# |    value_loss           | 0.000362    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -5.4e+03    |
# | time/                   |             |
# |    fps                  | 1329        |
# |    iterations           | 36          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.019922748 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28         |
# |    explained_variance   | 0.93063337  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0386     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.984       |
# |    value_loss           | 0.000204    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -5.26e+03   |
# | time/                   |             |
# |    fps                  | 1331        |
# |    iterations           | 37          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 303104      |
# | train/                  |             |
# |    approx_kl            | 0.013679773 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28         |
# |    explained_variance   | 0.7440477   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00238    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0093     |
# |    std                  | 0.985       |
# |    value_loss           | 0.000844    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -5.24e+03   |
# | time/                   |             |
# |    fps                  | 1330        |
# |    iterations           | 38          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.018670648 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.58963585  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0286     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.987       |
# |    value_loss           | 0.000366    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -5.23e+03   |
# | time/                   |             |
# |    fps                  | 1332        |
# |    iterations           | 39          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.020088533 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.9158993   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.035      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.987       |
# |    value_loss           | 0.000263    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -4.99e+03  |
# | time/                   |            |
# |    fps                  | 1333       |
# |    iterations           | 40         |
# |    time_elapsed         | 245        |
# |    total_timesteps      | 327680     |
# | train/                  |            |
# |    approx_kl            | 0.01811063 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.1      |
# |    explained_variance   | 0.9086808  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0214    |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0126    |
# |    std                  | 0.988      |
# |    value_loss           | 0.000211   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -4.89e+03   |
# | time/                   |             |
# |    fps                  | 1335        |
# |    iterations           | 41          |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 335872      |
# | train/                  |             |
# |    approx_kl            | 0.016753053 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.9055645   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0137     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.988       |
# |    value_loss           | 0.000509    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -4.75e+03  |
# | time/                   |            |
# |    fps                  | 1336       |
# |    iterations           | 42         |
# |    time_elapsed         | 257        |
# |    total_timesteps      | 344064     |
# | train/                  |            |
# |    approx_kl            | 0.02145159 |
# |    clip_fraction        | 0.231      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.1      |
# |    explained_variance   | 0.90908235 |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0538    |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0171    |
# |    std                  | 0.988      |
# |    value_loss           | 0.000345   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -4.67e+03   |
# | time/                   |             |
# |    fps                  | 1336        |
# |    iterations           | 43          |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 352256      |
# | train/                  |             |
# |    approx_kl            | 0.019211467 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.95551217  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0117      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0162     |
# |    std                  | 0.989       |
# |    value_loss           | 0.000167    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -4.84e+03   |
# | time/                   |             |
# |    fps                  | 1338        |
# |    iterations           | 44          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.019352857 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.94483584  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0421     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.989       |
# |    value_loss           | 0.00018     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -4.56e+03   |
# | time/                   |             |
# |    fps                  | 1338        |
# |    iterations           | 45          |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.017233608 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0.92217505  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0508     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.991       |
# |    value_loss           | 0.00043     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -4.38e+03   |
# | time/                   |             |
# |    fps                  | 1340        |
# |    iterations           | 46          |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.021313649 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0.9165549   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.05       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.994       |
# |    value_loss           | 0.000345    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -4.36e+03   |
# | time/                   |             |
# |    fps                  | 1340        |
# |    iterations           | 47          |
# |    time_elapsed         | 287         |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.017176038 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.3       |
# |    explained_variance   | 0.94781643  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00119     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.996       |
# |    value_loss           | 0.000382    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -4.18e+03   |
# | time/                   |             |
# |    fps                  | 1335        |
# |    iterations           | 48          |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.019266695 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0.9074796   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.993       |
# |    value_loss           | 0.000307    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -4.27e+03   |
# | time/                   |             |
# |    fps                  | 1335        |
# |    iterations           | 49          |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.019992188 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0.82569426  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.02       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 0.992       |
# |    value_loss           | 0.000312    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -4.21e+03  |
# | time/                   |            |
# |    fps                  | 1335       |
# |    iterations           | 50         |
# |    time_elapsed         | 306        |
# |    total_timesteps      | 409600     |
# | train/                  |            |
# |    approx_kl            | 0.01781426 |
# |    clip_fraction        | 0.23       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.2      |
# |    explained_variance   | 0.9439135  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0518    |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.0141    |
# |    std                  | 0.991      |
# |    value_loss           | 0.000525   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -4.19e+03   |
# | time/                   |             |
# |    fps                  | 1336        |
# |    iterations           | 51          |
# |    time_elapsed         | 312         |
# |    total_timesteps      | 417792      |
# | train/                  |             |
# |    approx_kl            | 0.018867426 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0.964731    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0179     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0143     |
# |    std                  | 0.994       |
# |    value_loss           | 0.0002      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -4.18e+03   |
# | time/                   |             |
# |    fps                  | 1336        |
# |    iterations           | 52          |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.019137386 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0.9258715   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0339     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.995       |
# |    value_loss           | 0.000282    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -4.05e+03   |
# | time/                   |             |
# |    fps                  | 1337        |
# |    iterations           | 53          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 434176      |
# | train/                  |             |
# |    approx_kl            | 0.024215743 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.2       |
# ...
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0159     |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.018      |
# |    std                  | 0.978       |
# |    value_loss           | 0.000414    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 982         |
# |    ep_rew_mean          | -3.58e+03   |
# | time/                   |             |
# |    fps                  | 1322        |
# |    iterations           | 82          |
# |    time_elapsed         | 507         |
# |    total_timesteps      | 671744      |
# | train/                  |             |
# |    approx_kl            | 0.025116526 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28         |
# |    explained_variance   | 0.9698384   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0495     |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.0174     |
# |    std                  | 0.982       |
# |    value_loss           | 0.000501    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 982         |
# |    ep_rew_mean          | -3.65e+03   |
# | time/                   |             |
# |    fps                  | 1321        |
# |    iterations           | 83          |
# |    time_elapsed         | 514         |
# |    total_timesteps      | 679936      |
# | train/                  |             |
# |    approx_kl            | 0.025133882 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28         |
# |    explained_variance   | 0.8900609   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00258     |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.979       |
# |    value_loss           | 0.000982    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 982        |
# |    ep_rew_mean          | -3.65e+03  |
# | time/                   |            |
# |    fps                  | 1321       |
# |    iterations           | 84         |
# |    time_elapsed         | 520        |
# |    total_timesteps      | 688128     |
# | train/                  |            |
# |    approx_kl            | 0.02385687 |
# |    clip_fraction        | 0.284      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -27.9      |
# |    explained_variance   | 0.9900949  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0318     |
# |    n_updates            | 830        |
# |    policy_gradient_loss | -0.0177    |
# |    std                  | 0.977      |
# |    value_loss           | 0.00053    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -3.55e+03   |
# | time/                   |             |
# |    fps                  | 1320        |
# |    iterations           | 85          |
# |    time_elapsed         | 527         |
# |    total_timesteps      | 696320      |
# | train/                  |             |
# |    approx_kl            | 0.020822674 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.9       |
# |    explained_variance   | 0.9706505   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.018       |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 0.978       |
# |    value_loss           | 0.000835    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -3.22e+03   |
# | time/                   |             |
# |    fps                  | 1320        |
# |    iterations           | 86          |
# |    time_elapsed         | 533         |
# |    total_timesteps      | 704512      |
# | train/                  |             |
# |    approx_kl            | 0.027830604 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.9       |
# |    explained_variance   | 0.9107025   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0489     |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.975       |
# |    value_loss           | 0.000564    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -3.08e+03   |
# | time/                   |             |
# |    fps                  | 1319        |
# |    iterations           | 87          |
# |    time_elapsed         | 540         |
# |    total_timesteps      | 712704      |
# | train/                  |             |
# |    approx_kl            | 0.022907704 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.8       |
# |    explained_variance   | 0.93969584  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0338     |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.974       |
# |    value_loss           | 0.000404    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -3.12e+03   |
# | time/                   |             |
# |    fps                  | 1318        |
# |    iterations           | 88          |
# |    time_elapsed         | 546         |
# |    total_timesteps      | 720896      |
# | train/                  |             |
# |    approx_kl            | 0.021796372 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.8       |
# |    explained_variance   | 0.9758278   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0451     |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 0.974       |
# |    value_loss           | 0.000272    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -3.07e+03   |
# | time/                   |             |
# |    fps                  | 1316        |
# |    iterations           | 89          |
# |    time_elapsed         | 553         |
# |    total_timesteps      | 729088      |
# | train/                  |             |
# |    approx_kl            | 0.020063465 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.8       |
# |    explained_variance   | 0.976798    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0198     |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.975       |
# |    value_loss           | 0.000257    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 982         |
# |    ep_rew_mean          | -3.02e+03   |
# | time/                   |             |
# |    fps                  | 1316        |
# |    iterations           | 90          |
# |    time_elapsed         | 560         |
# |    total_timesteps      | 737280      |
# | train/                  |             |
# |    approx_kl            | 0.020478684 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.8       |
# |    explained_variance   | 0.97689027  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0272     |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.975       |
# |    value_loss           | 0.00019     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 973         |
# |    ep_rew_mean          | -3.11e+03   |
# | time/                   |             |
# |    fps                  | 1315        |
# |    iterations           | 91          |
# |    time_elapsed         | 566         |
# |    total_timesteps      | 745472      |
# | train/                  |             |
# |    approx_kl            | 0.023990989 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.8       |
# |    explained_variance   | 0.86014223  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0435     |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.00909    |
# |    std                  | 0.976       |
# |    value_loss           | 0.00761     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 973         |
# |    ep_rew_mean          | -3.06e+03   |
# | time/                   |             |
# |    fps                  | 1315        |
# |    iterations           | 92          |
# |    time_elapsed         | 572         |
# |    total_timesteps      | 753664      |
# | train/                  |             |
# |    approx_kl            | 0.021940205 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.9       |
# |    explained_variance   | 0.942999    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00775     |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0132     |
# |    std                  | 0.978       |
# |    value_loss           | 0.00219     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 973         |
# |    ep_rew_mean          | -2.83e+03   |
# | time/                   |             |
# |    fps                  | 1315        |
# |    iterations           | 93          |
# |    time_elapsed         | 579         |
# |    total_timesteps      | 761856      |
# | train/                  |             |
# |    approx_kl            | 0.020846846 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.9       |
# |    explained_variance   | 0.9838874   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0227     |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0158     |
# |    std                  | 0.978       |
# |    value_loss           | 0.000456    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 973         |
# |    ep_rew_mean          | -2.54e+03   |
# | time/                   |             |
# |    fps                  | 1314        |
# |    iterations           | 94          |
# |    time_elapsed         | 585         |
# |    total_timesteps      | 770048      |
# | train/                  |             |
# |    approx_kl            | 0.017516479 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.9       |
# |    explained_variance   | 0.9420578   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0429     |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.976       |
# |    value_loss           | 0.000259    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 973         |
# |    ep_rew_mean          | -2.45e+03   |
# | time/                   |             |
# |    fps                  | 1312        |
# |    iterations           | 95          |
# |    time_elapsed         | 592         |
# |    total_timesteps      | 778240      |
# | train/                  |             |
# |    approx_kl            | 0.019463258 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.9       |
# |    explained_variance   | 0.79841334  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00613    |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 0.976       |
# |    value_loss           | 0.000837    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 973         |
# |    ep_rew_mean          | -2.39e+03   |
# | time/                   |             |
# |    fps                  | 1312        |
# |    iterations           | 96          |
# |    time_elapsed         | 599         |
# |    total_timesteps      | 786432      |
# | train/                  |             |
# |    approx_kl            | 0.022706032 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.9       |
# |    explained_variance   | 0.69344306  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0308     |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 0.976       |
# |    value_loss           | 0.000723    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 973         |
# |    ep_rew_mean          | -2.31e+03   |
# | time/                   |             |
# |    fps                  | 1310        |
# |    iterations           | 97          |
# |    time_elapsed         | 606         |
# |    total_timesteps      | 794624      |
# | train/                  |             |
# |    approx_kl            | 0.022118451 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.8       |
# |    explained_variance   | 0.9465509   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0213     |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0172     |
# |    std                  | 0.974       |
# |    value_loss           | 0.000224    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 973         |
# |    ep_rew_mean          | -2.26e+03   |
# | time/                   |             |
# |    fps                  | 1309        |
# |    iterations           | 98          |
# |    time_elapsed         | 613         |
# |    total_timesteps      | 802816      |
# | train/                  |             |
# |    approx_kl            | 0.022856202 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.8       |
# |    explained_variance   | 0.96627074  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0301     |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.976       |
# |    value_loss           | 0.000236    |
# -----------------------------------------

# %%
model.learn(1600000,tb_log_name='reshape_v2',callback=eval_callback,reset_num_timesteps=False)
# Out:
# Logging to logs/reshape/reshape_v2_17
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 237      |
# |    ep_rew_mean     | 52.5     |
# | time/              |          |
# |    fps             | 2248     |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 4222272  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 272         |
# |    ep_rew_mean          | -5.02       |
# | time/                   |             |
# |    fps                  | 1392        |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4230464     |
# | train/                  |             |
# |    approx_kl            | 0.052151516 |
# |    clip_fraction        | 0.456       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.7       |
# |    explained_variance   | 0.6771345   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0513     |
# |    n_updates            | 5130        |
# |    policy_gradient_loss | -0.0274     |
# |    std                  | 0.756       |
# |    value_loss           | 0.0396      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 224        |
# |    ep_rew_mean          | 113        |
# | time/                   |            |
# |    fps                  | 1274       |
# |    iterations           | 3          |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 4238656    |
# | train/                  |            |
# |    approx_kl            | 0.0494247  |
# |    clip_fraction        | 0.44       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.7      |
# |    explained_variance   | 0.75647897 |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0448    |
# |    n_updates            | 5140       |
# |    policy_gradient_loss | -0.0258    |
# |    std                  | 0.755      |
# |    value_loss           | 0.0299     |
# ----------------------------------------
# Eval num_timesteps=4242816, episode_reward=96.77 +/- 562.40
# Episode length: 196.53 +/- 229.47
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 197         |
# |    mean_reward          | 96.8        |
# | time/                   |             |
# |    total_timesteps      | 4242816     |
# | train/                  |             |
# |    approx_kl            | 0.052575245 |
# |    clip_fraction        | 0.443       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.7       |
# |    explained_variance   | 0.75388056  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.056      |
# |    n_updates            | 5150        |
# |    policy_gradient_loss | -0.0292     |
# |    std                  | 0.755       |
# |    value_loss           | 0.0333      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | 143      |
# | time/              |          |
# |    fps             | 1099     |
# |    iterations      | 4        |
# |    time_elapsed    | 29       |
# |    total_timesteps | 4246848  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 198        |
# |    ep_rew_mean          | 170        |
# | time/                   |            |
# |    fps                  | 1097       |
# |    iterations           | 5          |
# |    time_elapsed         | 37         |
# |    total_timesteps      | 4255040    |
# | train/                  |            |
# |    approx_kl            | 0.05501226 |
# |    clip_fraction        | 0.452      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.6      |
# |    explained_variance   | 0.6365864  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0604    |
# |    n_updates            | 5160       |
# |    policy_gradient_loss | -0.0303    |
# |    std                  | 0.752      |
# |    value_loss           | 0.0425     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 192        |
# |    ep_rew_mean          | 177        |
# | time/                   |            |
# |    fps                  | 1090       |
# |    iterations           | 6          |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 4263232    |
# | train/                  |            |
# |    approx_kl            | 0.05240471 |
# |    clip_fraction        | 0.446      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.6      |
# |    explained_variance   | 0.7273363  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0215    |
# |    n_updates            | 5170       |
# |    policy_gradient_loss | -0.0248    |
# |    std                  | 0.752      |
# |    value_loss           | 0.0359     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 213        |
# |    ep_rew_mean          | 146        |
# | time/                   |            |
# |    fps                  | 1085       |
# |    iterations           | 7          |
# |    time_elapsed         | 52         |
# |    total_timesteps      | 4271424    |
# | train/                  |            |
# |    approx_kl            | 0.05271815 |
# |    clip_fraction        | 0.448      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.5      |
# |    explained_variance   | 0.7045398  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0354    |
# |    n_updates            | 5180       |
# |    policy_gradient_loss | -0.0277    |
# |    std                  | 0.749      |
# |    value_loss           | 0.0438     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 214         |
# |    ep_rew_mean          | 123         |
# | time/                   |             |
# |    fps                  | 1075        |
# |    iterations           | 8           |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 4279616     |
# | train/                  |             |
# |    approx_kl            | 0.052424625 |
# |    clip_fraction        | 0.45        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 0.7504911   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0083     |
# |    n_updates            | 5190        |
# |    policy_gradient_loss | -0.026      |
# |    std                  | 0.747       |
# |    value_loss           | 0.0349      |
# -----------------------------------------
# Eval num_timesteps=4282816, episode_reward=-11.01 +/- 509.30
# Episode length: 309.87 +/- 260.01
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 310         |
# |    mean_reward          | -11         |
# | time/                   |             |
# |    total_timesteps      | 4282816     |
# | train/                  |             |
# |    approx_kl            | 0.054347854 |
# |    clip_fraction        | 0.45        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 0.8389433   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00905     |
# |    n_updates            | 5200        |
# |    policy_gradient_loss | -0.0271     |
# |    std                  | 0.746       |
# |    value_loss           | 0.0233      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 233      |
# |    ep_rew_mean     | 90.9     |
# | time/              |          |
# |    fps             | 1038     |
# |    iterations      | 9        |
# |    time_elapsed    | 71       |
# |    total_timesteps | 4287808  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 227         |
# |    ep_rew_mean          | 84.6        |
# | time/                   |             |
# |    fps                  | 1052        |
# |    iterations           | 10          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 4296000     |
# | train/                  |             |
# |    approx_kl            | 0.051358912 |
# |    clip_fraction        | 0.442       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 0.7962682   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0253     |
# |    n_updates            | 5210        |
# |    policy_gradient_loss | -0.025      |
# |    std                  | 0.746       |
# |    value_loss           | 0.0251      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 240         |
# |    ep_rew_mean          | 82.7        |
# | time/                   |             |
# |    fps                  | 1064        |
# |    iterations           | 11          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 4304192     |
# | train/                  |             |
# |    approx_kl            | 0.052921962 |
# |    clip_fraction        | 0.45        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 0.8015311   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0433     |
# |    n_updates            | 5220        |
# |    policy_gradient_loss | -0.0264     |
# |    std                  | 0.746       |
# |    value_loss           | 0.0364      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 193         |
# |    ep_rew_mean          | 146         |
# | time/                   |             |
# |    fps                  | 1075        |
# |    iterations           | 12          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 4312384     |
# | train/                  |             |
# |    approx_kl            | 0.052728355 |
# |    clip_fraction        | 0.448       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 0.7486042   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0145     |
# |    n_updates            | 5230        |
# |    policy_gradient_loss | -0.0242     |
# |    std                  | 0.744       |
# |    value_loss           | 0.031       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 163         |
# |    ep_rew_mean          | 179         |
# | time/                   |             |
# |    fps                  | 1083        |
# |    iterations           | 13          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 4320576     |
# | train/                  |             |
# |    approx_kl            | 0.056868922 |
# |    clip_fraction        | 0.457       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.3       |
# |    explained_variance   | 0.74050033  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0607     |
# |    n_updates            | 5240        |
# |    policy_gradient_loss | -0.0248     |
# |    std                  | 0.744       |
# |    value_loss           | 0.0416      |
# -----------------------------------------
# Eval num_timesteps=4322816, episode_reward=253.43 +/- 132.03
# Episode length: 126.73 +/- 101.73
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 127         |
# |    mean_reward          | 253         |
# | time/                   |             |
# |    total_timesteps      | 4322816     |
# | train/                  |             |
# |    approx_kl            | 0.055320747 |
# |    clip_fraction        | 0.456       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.3       |
# |    explained_variance   | 0.72722614  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0242      |
# |    n_updates            | 5250        |
# |    policy_gradient_loss | -0.0241     |
# |    std                  | 0.743       |
# |    value_loss           | 0.0349      |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 178      |
# |    ep_rew_mean     | 156      |
# | time/              |          |
# |    fps             | 1073     |
# |    iterations      | 14       |
# |    time_elapsed    | 106      |
# |    total_timesteps | 4328768  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 241         |
# |    ep_rew_mean          | 9.54        |
# | time/                   |             |
# |    fps                  | 1074        |
# |    iterations           | 15          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 4336960     |
# | train/                  |             |
# |    approx_kl            | 0.047855962 |
# |    clip_fraction        | 0.429       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.3       |
# |    explained_variance   | 0.8180786   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0387     |
# |    n_updates            | 5260        |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 0.743       |
# |    value_loss           | 0.0212      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 272         |
# |    ep_rew_mean          | -28.5       |
# | time/                   |             |
# |    fps                  | 1068        |
# |    iterations           | 16          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 4345152     |
# | train/                  |             |
# |    approx_kl            | 0.050225377 |
# |    clip_fraction        | 0.439       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.3       |
# |    explained_variance   | 0.89911973  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0579     |
# |    n_updates            | 5270        |
# |    policy_gradient_loss | -0.0253     |
# |    std                  | 0.743       |
# |    value_loss           | 0.0229      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 299        |
# |    ep_rew_mean          | -67.7      |
# | time/                   |            |
# |    fps                  | 1077       |
# |    iterations           | 17         |
# |    time_elapsed         | 129        |
# |    total_timesteps      | 4353344    |
# | train/                  |            |
# |    approx_kl            | 0.05397377 |
# |    clip_fraction        | 0.455      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.3      |
# |    explained_variance   | 0.8026894  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0525    |
# |    n_updates            | 5280       |
# |    policy_gradient_loss | -0.0273    |
# |    std                  | 0.745      |
# |    value_loss           | 0.0332     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 270         |
# |    ep_rew_mean          | -4.84       |
# | time/                   |             |
# |    fps                  | 1084        |
# |    iterations           | 18          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 4361536     |
# | train/                  |             |
# |    approx_kl            | 0.056457527 |
# |    clip_fraction        | 0.464       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 0.79037756  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0285     |
# |    n_updates            | 5290        |
# |    policy_gradient_loss | -0.0243     |
# |    std                  | 0.746       |
# |    value_loss           | 0.0335      |
# -----------------------------------------
# Eval num_timesteps=4362816, episode_reward=173.65 +/- 142.25
# Episode length: 193.40 +/- 114.53
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 193         |
# |    mean_reward          | 174         |
# | time/                   |             |
# |    total_timesteps      | 4362816     |
# | train/                  |             |
# |    approx_kl            | 0.055020705 |
# |    clip_fraction        | 0.45        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 0.89075226  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0428     |
# |    n_updates            | 5300        |
# |    policy_gradient_loss | -0.029      |
# |    std                  | 0.747       |
# |    value_loss           | 0.0269      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 269      |
# |    ep_rew_mean     | -34.5    |
# | time/              |          |
# |    fps             | 1074     |
# |    iterations      | 19       |
# |    time_elapsed    | 144      |
# |    total_timesteps | 4369728  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 252        |
# |    ep_rew_mean          | 6.03       |
# | time/                   |            |
# |    fps                  | 1082       |
# |    iterations           | 20         |
# |    time_elapsed         | 151        |
# |    total_timesteps      | 4377920    |
# | train/                  |            |
# |    approx_kl            | 0.05444766 |
# |    clip_fraction        | 0.442      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.4      |
# |    explained_variance   | 0.8919021  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0293    |
# |    n_updates            | 5310       |
# |    policy_gradient_loss | -0.0246    |
# |    std                  | 0.748      |
# |    value_loss           | 0.0254     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 210         |
# |    ep_rew_mean          | 111         |
# | time/                   |             |
# |    fps                  | 1087        |
# |    iterations           | 21          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 4386112     |
# | train/                  |             |
# |    approx_kl            | 0.049832642 |
# |    clip_fraction        | 0.436       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 0.78182995  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0143     |
# |    n_updates            | 5320        |
# |    policy_gradient_loss | -0.0235     |
# |    std                  | 0.747       |
# |    value_loss           | 0.0392      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 188         |
# |    ep_rew_mean          | 158         |
# | time/                   |             |
# |    fps                  | 1091        |
# |    iterations           | 22          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 4394304     |
# | train/                  |             |
# |    approx_kl            | 0.051599484 |
# |    clip_fraction        | 0.454       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.5       |
# |    explained_variance   | 0.775849    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00327    |
# |    n_updates            | 5330        |
# |    policy_gradient_loss | -0.0255     |
# |    std                  | 0.748       |
# |    value_loss           | 0.0369      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 158        |
# |    ep_rew_mean          | 223        |
# | time/                   |            |
# |    fps                  | 1093       |
# |    iterations           | 23         |
# |    time_elapsed         | 172        |
# |    total_timesteps      | 4402496    |
# | train/                  |            |
# |    approx_kl            | 0.05003197 |
# |    clip_fraction        | 0.443      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.4      |
# |    explained_variance   | 0.7849543  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0697    |
# |    n_updates            | 5340       |
# |    policy_gradient_loss | -0.0251    |
# |    std                  | 0.746      |
# |    value_loss           | 0.0413     |
# ----------------------------------------
# Eval num_timesteps=4402816, episode_reward=205.46 +/- 130.55
# Episode length: 183.47 +/- 148.14
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 183         |
# |    mean_reward          | 205         |
# | time/                   |             |
# |    total_timesteps      | 4402816     |
# | train/                  |             |
# |    approx_kl            | 0.049566884 |
# |    clip_fraction        | 0.45        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 0.7416402   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00145     |
# |    n_updates            | 5350        |
# |    policy_gradient_loss | -0.0211     |
# |    std                  | 0.745       |
# |    value_loss           | 0.0433      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 181      |
# |    ep_rew_mean     | 184      |
# | time/              |          |
# |    fps             | 1085     |
# |    iterations      | 24       |
# |    time_elapsed    | 181      |
# |    total_timesteps | 4410688  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 212         |
# |    ep_rew_mean          | 138         |
# | time/                   |             |
# |    fps                  | 1089        |
# |    iterations           | 25          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 4418880     |
# | train/                  |             |
# |    approx_kl            | 0.052849192 |
# |    clip_fraction        | 0.45        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.3       |
# |    explained_variance   | 0.7568395   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0143     |
# |    n_updates            | 5360        |
# |    policy_gradient_loss | -0.0236     |
# |    std                  | 0.744       |
# |    value_loss           | 0.0333      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 203        |
# |    ep_rew_mean          | 160        |
# | time/                   |            |
# |    fps                  | 1095       |
# |    iterations           | 26         |
# |    time_elapsed         | 194        |
# |    total_timesteps      | 4427072    |
# | train/                  |            |
# |    approx_kl            | 0.05636758 |
# |    clip_fraction        | 0.469      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.3      |
# |    explained_variance   | 0.7156504  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0616    |
# |    n_updates            | 5370       |
# |    policy_gradient_loss | -0.0288    |
# |    std                  | 0.744      |
# |    value_loss           | 0.0361     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 177         |
# |    ep_rew_mean          | 195         |
# | time/                   |             |
# |    fps                  | 1097        |
# |    iterations           | 27          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 4435264     |
# | train/                  |             |
# |    approx_kl            | 0.055230055 |
# |    clip_fraction        | 0.466       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 0.7625686   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 5380        |
# |    policy_gradient_loss | -0.0271     |
# |    std                  | 0.745       |
# |    value_loss           | 0.0412      |
# -----------------------------------------
# Eval num_timesteps=4442816, episode_reward=132.46 +/- 351.53
# Episode length: 236.40 +/- 280.09
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 236         |
# |    mean_reward          | 132         |
# | time/                   |             |
# |    total_timesteps      | 4442816     |
# | train/                  |             |
# |    approx_kl            | 0.055610478 |
# |    clip_fraction        | 0.451       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.3       |
# |    explained_variance   | 0.7474704   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0197     |
# |    n_updates            | 5390        |
# |    policy_gradient_loss | -0.0263     |
# |    std                  | 0.743       |
# |    value_loss           | 0.0475      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 201      |
# |    ep_rew_mean     | 168      |
# | time/              |          |
# |    fps             | 1088     |
# |    iterations      | 28       |
# |    time_elapsed    | 210      |
# |    total_timesteps | 4443456  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 222        |
# |    ep_rew_mean          | 136        |
# | time/                   |            |
# |    fps                  | 1093       |
# |    iterations           | 29         |
# |    time_elapsed         | 217        |
# |    total_timesteps      | 4451648    |
# | train/                  |            |
# |    approx_kl            | 0.05347085 |
# |    clip_fraction        | 0.454      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.3      |
# |    explained_variance   | 0.76222247 |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00876   |
# |    n_updates            | 5400       |
# |    policy_gradient_loss | -0.0295    |
# |    std                  | 0.742      |
# |    value_loss           | 0.0414     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 214         |
# |    ep_rew_mean          | 138         |
# | time/                   |             |
# |    fps                  | 1097        |
# |    iterations           | 30          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 4459840     |
# | train/                  |             |
# |    approx_kl            | 0.055629924 |
# |    clip_fraction        | 0.461       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.3       |
# |    explained_variance   | 0.77912945  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0378     |
# |    n_updates            | 5410        |
# |    policy_gradient_loss | -0.028      |
# |    std                  | 0.742       |
# |    value_loss           | 0.0391      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 185         |
# |    ep_rew_mean          | 190         |
# | time/                   |             |
# |    fps                  | 1102        |
# |    iterations           | 31          |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 4468032     |
# | train/                  |             |
# |    approx_kl            | 0.054205988 |
# |    clip_fraction        | 0.46        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.3       |
# |    explained_variance   | 0.7968602   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.036      |
# |    n_updates            | 5420        |
# |    policy_gradient_loss | -0.0263     |
# |    std                  | 0.741       |
# |    value_loss           | 0.0428      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 182        |
# |    ep_rew_mean          | 204        |
# | time/                   |            |
# |    fps                  | 1106       |
# |    iterations           | 32         |
# |    time_elapsed         | 236        |
# |    total_timesteps      | 4476224    |
# | train/                  |            |
# |    approx_kl            | 0.05369498 |
# |    clip_fraction        | 0.455      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.3      |
# |    explained_variance   | 0.7533218  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0162    |
# |    n_updates            | 5430       |
# |    policy_gradient_loss | -0.0257    |
# |    std                  | 0.741      |
# |    value_loss           | 0.0447     |
# ----------------------------------------
# Eval num_timesteps=4482816, episode_reward=226.68 +/- 138.76
# Episode length: 172.87 +/- 139.96
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 173         |
# |    mean_reward          | 227         |
# | time/                   |             |
# |    total_timesteps      | 4482816     |
# | train/                  |             |
# |    approx_kl            | 0.053351633 |
# |    clip_fraction        | 0.449       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.3       |
# |    explained_variance   | 0.74177945  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00327     |
# |    n_updates            | 5440        |
# |    policy_gradient_loss | -0.0258     |
# |    std                  | 0.742       |
# |    value_loss           | 0.048       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 196      |
# |    ep_rew_mean     | 185      |
# | time/              |          |
# |    fps             | 1100     |
# |    iterations      | 33       |
# |    time_elapsed    | 245      |
# |    total_timesteps | 4484416  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 205         |
# |    ep_rew_mean          | 171         |
# | time/                   |             |
# |    fps                  | 1105        |
# |    iterations           | 34          |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 4492608     |
# | train/                  |             |
# |    approx_kl            | 0.056890726 |
# |    clip_fraction        | 0.45        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.64226866  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.038      |
# |    n_updates            | 5450        |
# |    policy_gradient_loss | -0.0259     |
# |    std                  | 0.741       |
# |    value_loss           | 0.045       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 229         |
# |    ep_rew_mean          | 111         |
# | time/                   |             |
# |    fps                  | 1109        |
# |    iterations           | 35          |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 4500800     |
# | train/                  |             |
# |    approx_kl            | 0.055161923 |
# |    clip_fraction        | 0.461       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.63650656  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0187     |
# |    n_updates            | 5460        |
# |    policy_gradient_loss | -0.0262     |
# |    std                  | 0.74        |
# |    value_loss           | 0.0527      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 212         |
# |    ep_rew_mean          | 131         |
# | time/                   |             |
# |    fps                  | 1113        |
# |    iterations           | 36          |
# |    time_elapsed         | 264         |
# |    total_timesteps      | 4508992     |
# | train/                  |             |
# |    approx_kl            | 0.051948946 |
# |    clip_fraction        | 0.449       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.84494466  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0355     |
# |    n_updates            | 5470        |
# |    policy_gradient_loss | -0.0243     |
# |    std                  | 0.74        |
# |    value_loss           | 0.037       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 235         |
# |    ep_rew_mean          | 99.9        |
# | time/                   |             |
# |    fps                  | 1116        |
# |    iterations           | 37          |
# |    time_elapsed         | 271         |
# |    total_timesteps      | 4517184     |
# | train/                  |             |
# |    approx_kl            | 0.052307747 |
# |    clip_fraction        | 0.45        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.7772732   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0145     |
# |    n_updates            | 5480        |
# |    policy_gradient_loss | -0.0234     |
# |    std                  | 0.74        |
# |    value_loss           | 0.036       |
# -----------------------------------------
# Eval num_timesteps=4522816, episode_reward=157.15 +/- 137.47
# Episode length: 225.80 +/- 147.37
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 226         |
# |    mean_reward          | 157         |
# | time/                   |             |
# |    total_timesteps      | 4522816     |
# | train/                  |             |
# |    approx_kl            | 0.050468348 |
# |    clip_fraction        | 0.441       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.8004256   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0389     |
# |    n_updates            | 5490        |
# |    policy_gradient_loss | -0.0215     |
# |    std                  | 0.741       |
# |    value_loss           | 0.0334      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 230      |
# |    ep_rew_mean     | 134      |
# | time/              |          |
# |    fps             | 1108     |
# |    iterations      | 38       |
# |    time_elapsed    | 280      |
# |    total_timesteps | 4525376  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 249         |
# |    ep_rew_mean          | 96.8        |
# | time/                   |             |
# |    fps                  | 1104        |
# |    iterations           | 39          |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 4533568     |
# | train/                  |             |
# |    approx_kl            | 0.058096983 |
# |    clip_fraction        | 0.458       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.78891075  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0443     |
# |    n_updates            | 5500        |
# |    policy_gradient_loss | -0.026      |
# |    std                  | 0.738       |
# |    value_loss           | 0.0307      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 238         |
# |    ep_rew_mean          | 88.6        |
# | time/                   |             |
# |    fps                  | 1105        |
# |    iterations           | 40          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 4541760     |
# | train/                  |             |
# |    approx_kl            | 0.058425575 |
# |    clip_fraction        | 0.468       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.72953093  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.031      |
# |    n_updates            | 5510        |
# |    policy_gradient_loss | -0.0297     |
# |    std                  | 0.739       |
# |    value_loss           | 0.0386      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 207        |
# |    ep_rew_mean          | 127        |
# | time/                   |            |
# |    fps                  | 1104       |
# |    iterations           | 41         |
# |    time_elapsed         | 304        |
# |    total_timesteps      | 4549952    |
# | train/                  |            |
# |    approx_kl            | 0.05237181 |
# |    clip_fraction        | 0.45       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.2      |
# |    explained_variance   | 0.80213773 |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0691    |
# |    n_updates            | 5520       |
# |    policy_gradient_loss | -0.0259    |
# |    std                  | 0.739      |
# |    value_loss           | 0.0337     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | 153         |
# | time/                   |             |
# |    fps                  | 1104        |
# |    iterations           | 42          |
# |    time_elapsed         | 311         |
# |    total_timesteps      | 4558144     |
# | train/                  |             |
# |    approx_kl            | 0.054676265 |
# |    clip_fraction        | 0.459       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.702973    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0303     |
# |    n_updates            | 5530        |
# |    policy_gradient_loss | -0.0279     |
# |    std                  | 0.74        |
# |    value_loss           | 0.0419      |
# -----------------------------------------
# Eval num_timesteps=4562816, episode_reward=88.47 +/- 367.90
# Episode length: 250.47 +/- 227.08
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 250        |
# |    mean_reward          | 88.5       |
# | time/                   |            |
# |    total_timesteps      | 4562816    |
# | train/                  |            |
# |    approx_kl            | 0.05566235 |
# |    clip_fraction        | 0.458      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.2      |
# |    explained_variance   | 0.7301633  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.004      |
# |    n_updates            | 5540       |
# |    policy_gradient_loss | -0.0266    |
# |    std                  | 0.739      |
# |    value_loss           | 0.0372     |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 192      |
# |    ep_rew_mean     | 166      |
# | time/              |          |
# |    fps             | 1098     |
# |    iterations      | 43       |
# |    time_elapsed    | 320      |
# |    total_timesteps | 4566336  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 207        |
# |    ep_rew_mean          | 150        |
# | time/                   |            |
# |    fps                  | 1101       |
# |    iterations           | 44         |
# |    time_elapsed         | 327        |
# |    total_timesteps      | 4574528    |
# | train/                  |            |
# |    approx_kl            | 0.05145725 |
# |    clip_fraction        | 0.452      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.2      |
# |    explained_variance   | 0.6815659  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0386    |
# |    n_updates            | 5550       |
# |    policy_gradient_loss | -0.0265    |
# |    std                  | 0.737      |
# |    value_loss           | 0.0454     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 212        |
# |    ep_rew_mean          | 164        |
# | time/                   |            |
# |    fps                  | 1104       |
# |    iterations           | 45         |
# |    time_elapsed         | 333        |
# |    total_timesteps      | 4582720    |
# | train/                  |            |
# |    approx_kl            | 0.05241436 |
# |    clip_fraction        | 0.454      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.1      |
# |    explained_variance   | 0.6205429  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00975   |
# |    n_updates            | 5560       |
# |    policy_gradient_loss | -0.0239    |
# |    std                  | 0.737      |
# |    value_loss           | 0.0504     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 217         |
# |    ep_rew_mean          | 159         |
# | time/                   |             |
# |    fps                  | 1107        |
# |    iterations           | 46          |
# |    time_elapsed         | 340         |
# |    total_timesteps      | 4590912     |
# | train/                  |             |
# |    approx_kl            | 0.059032902 |
# |    clip_fraction        | 0.463       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.65922767  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0344     |
# |    n_updates            | 5570        |
# |    policy_gradient_loss | -0.0222     |
# |    std                  | 0.738       |
# |    value_loss           | 0.0539      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 214         |
# |    ep_rew_mean          | 144         |
# | time/                   |             |
# |    fps                  | 1110        |
# |    iterations           | 47          |
# |    time_elapsed         | 346         |
# |    total_timesteps      | 4599104     |
# | train/                  |             |
# |    approx_kl            | 0.058718093 |
# |    clip_fraction        | 0.467       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.7067461   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0104      |
# |    n_updates            | 5580        |
# |    policy_gradient_loss | -0.0257     |
# |    std                  | 0.738       |
# |    value_loss           | 0.044       |
# -----------------------------------------
# Eval num_timesteps=4602816, episode_reward=224.69 +/- 120.65
# Episode length: 168.00 +/- 135.99
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 168         |
# |    mean_reward          | 225         |
# | time/                   |             |
# |    total_timesteps      | 4602816     |
# | train/                  |             |
# |    approx_kl            | 0.054248877 |
# |    clip_fraction        | 0.462       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.83889246  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0411     |
# |    n_updates            | 5590        |
# |    policy_gradient_loss | -0.028      |
# |    std                  | 0.738       |
# |    value_loss           | 0.0317      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 202      |
# |    ep_rew_mean     | 145      |
# | time/              |          |
# |    fps             | 1108     |
# |    iterations      | 48       |
# |    time_elapsed    | 354      |
# |    total_timesteps | 4607296  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 184         |
# |    ep_rew_mean          | 175         |
# | time/                   |             |
# |    fps                  | 1110        |
# |    iterations           | 49          |
# |    time_elapsed         | 361         |
# |    total_timesteps      | 4615488     |
# | train/                  |             |
# |    approx_kl            | 0.053810682 |
# |    clip_fraction        | 0.458       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.1       |
# |    explained_variance   | 0.72759426  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0348     |
# |    n_updates            | 5600        |
# |    policy_gradient_loss | -0.0253     |
# |    std                  | 0.737       |
# |    value_loss           | 0.0469      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 176         |
# |    ep_rew_mean          | 179         |
# | time/                   |             |
# |    fps                  | 1113        |
# |    iterations           | 50          |
# |    time_elapsed         | 367         |
# |    total_timesteps      | 4623680     |
# | train/                  |             |
# |    approx_kl            | 0.059848808 |
# ...
# |    policy_gradient_loss | -0.0283    |
# |    std                  | 0.662      |
# |    value_loss           | 0.0315     |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 183      |
# |    ep_rew_mean     | 143      |
# | time/              |          |
# |    fps             | 1140     |
# |    iterations      | 180      |
# |    time_elapsed    | 1292     |
# |    total_timesteps | 5688640  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 160        |
# |    ep_rew_mean          | 210        |
# | time/                   |            |
# |    fps                  | 1140       |
# |    iterations           | 181        |
# |    time_elapsed         | 1300       |
# |    total_timesteps      | 5696832    |
# | train/                  |            |
# |    approx_kl            | 0.06885993 |
# |    clip_fraction        | 0.502      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -19.9      |
# |    explained_variance   | 0.73747975 |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0379    |
# |    n_updates            | 6920       |
# |    policy_gradient_loss | -0.0275    |
# |    std                  | 0.661      |
# |    value_loss           | 0.0476     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 220         |
# | time/                   |             |
# |    fps                  | 1139        |
# |    iterations           | 182         |
# |    time_elapsed         | 1308        |
# |    total_timesteps      | 5705024     |
# | train/                  |             |
# |    approx_kl            | 0.072044715 |
# |    clip_fraction        | 0.504       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -19.9       |
# |    explained_variance   | 0.7802395   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0363     |
# |    n_updates            | 6930        |
# |    policy_gradient_loss | -0.0281     |
# |    std                  | 0.662       |
# |    value_loss           | 0.0442      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 172        |
# |    ep_rew_mean          | 184        |
# | time/                   |            |
# |    fps                  | 1139       |
# |    iterations           | 183        |
# |    time_elapsed         | 1315       |
# |    total_timesteps      | 5713216    |
# | train/                  |            |
# |    approx_kl            | 0.07313764 |
# |    clip_fraction        | 0.51       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -19.9      |
# |    explained_variance   | 0.7579577  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0211     |
# |    n_updates            | 6940       |
# |    policy_gradient_loss | -0.0306    |
# |    std                  | 0.661      |
# |    value_loss           | 0.0472     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 177        |
# |    ep_rew_mean          | 157        |
# | time/                   |            |
# |    fps                  | 1139       |
# |    iterations           | 184        |
# |    time_elapsed         | 1322       |
# |    total_timesteps      | 5721408    |
# | train/                  |            |
# |    approx_kl            | 0.07091827 |
# |    clip_fraction        | 0.515      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -19.9      |
# |    explained_variance   | 0.7575791  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.054     |
# |    n_updates            | 6950       |
# |    policy_gradient_loss | -0.0293    |
# |    std                  | 0.661      |
# |    value_loss           | 0.0447     |
# ----------------------------------------
# Eval num_timesteps=5722816, episode_reward=129.40 +/- 327.80
# Episode length: 196.60 +/- 218.91
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 197        |
# |    mean_reward          | 129        |
# | time/                   |            |
# |    total_timesteps      | 5722816    |
# | train/                  |            |
# |    approx_kl            | 0.06876288 |
# |    clip_fraction        | 0.505      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -19.9      |
# |    explained_variance   | 0.81806964 |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0223    |
# |    n_updates            | 6960       |
# |    policy_gradient_loss | -0.0273    |
# |    std                  | 0.661      |
# |    value_loss           | 0.0328     |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 170      |
# |    ep_rew_mean     | 157      |
# | time/              |          |
# |    fps             | 1138     |
# |    iterations      | 185      |
# |    time_elapsed    | 1331     |
# |    total_timesteps | 5729600  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 153        |
# |    ep_rew_mean          | 196        |
# | time/                   |            |
# |    fps                  | 1139       |
# |    iterations           | 186        |
# |    time_elapsed         | 1337       |
# |    total_timesteps      | 5737792    |
# | train/                  |            |
# |    approx_kl            | 0.07375045 |
# |    clip_fraction        | 0.515      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -19.8      |
# |    explained_variance   | 0.74467224 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00431    |
# |    n_updates            | 6970       |
# |    policy_gradient_loss | -0.0301    |
# |    std                  | 0.659      |
# |    value_loss           | 0.0523     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | 223         |
# | time/                   |             |
# |    fps                  | 1138        |
# |    iterations           | 187         |
# |    time_elapsed         | 1345        |
# |    total_timesteps      | 5745984     |
# | train/                  |             |
# |    approx_kl            | 0.070268944 |
# |    clip_fraction        | 0.502       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -19.8       |
# |    explained_variance   | 0.71984154  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0156     |
# |    n_updates            | 6980        |
# |    policy_gradient_loss | -0.0267     |
# |    std                  | 0.658       |
# |    value_loss           | 0.0536      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 161       |
# |    ep_rew_mean          | 186       |
# | time/                   |           |
# |    fps                  | 1139      |
# |    iterations           | 188       |
# |    time_elapsed         | 1352      |
# |    total_timesteps      | 5754176   |
# | train/                  |           |
# |    approx_kl            | 0.0704464 |
# |    clip_fraction        | 0.512     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -19.8     |
# |    explained_variance   | 0.7505263 |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0343   |
# |    n_updates            | 6990      |
# |    policy_gradient_loss | -0.0273   |
# |    std                  | 0.658     |
# |    value_loss           | 0.0522    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 166         |
# |    ep_rew_mean          | 189         |
# | time/                   |             |
# |    fps                  | 1139        |
# |    iterations           | 189         |
# |    time_elapsed         | 1358        |
# |    total_timesteps      | 5762368     |
# | train/                  |             |
# |    approx_kl            | 0.079028994 |
# |    clip_fraction        | 0.516       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -19.8       |
# |    explained_variance   | 0.53634524  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0172     |
# |    n_updates            | 7000        |
# |    policy_gradient_loss | -0.0239     |
# |    std                  | 0.657       |
# |    value_loss           | 0.0532      |
# -----------------------------------------
# Eval num_timesteps=5762816, episode_reward=265.39 +/- 154.33
# Episode length: 112.13 +/- 94.59
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 112         |
# |    mean_reward          | 265         |
# | time/                   |             |
# |    total_timesteps      | 5762816     |
# | train/                  |             |
# |    approx_kl            | 0.071282715 |
# |    clip_fraction        | 0.509       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -19.8       |
# |    explained_variance   | 0.7373078   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000852   |
# |    n_updates            | 7010        |
# |    policy_gradient_loss | -0.0252     |
# |    std                  | 0.658       |
# |    value_loss           | 0.0512      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | 222      |
# | time/              |          |
# |    fps             | 1138     |
# |    iterations      | 190      |
# |    time_elapsed    | 1366     |
# |    total_timesteps | 5770560  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 140        |
# |    ep_rew_mean          | 202        |
# | time/                   |            |
# |    fps                  | 1139       |
# |    iterations           | 191        |
# |    time_elapsed         | 1373       |
# |    total_timesteps      | 5778752    |
# | train/                  |            |
# |    approx_kl            | 0.07087937 |
# |    clip_fraction        | 0.503      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -19.8      |
# |    explained_variance   | 0.7991468  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.000688   |
# |    n_updates            | 7020       |
# |    policy_gradient_loss | -0.0271    |
# |    std                  | 0.657      |
# |    value_loss           | 0.048      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 164        |
# |    ep_rew_mean          | 162        |
# | time/                   |            |
# |    fps                  | 1139       |
# |    iterations           | 192        |
# |    time_elapsed         | 1379       |
# |    total_timesteps      | 5786944    |
# | train/                  |            |
# |    approx_kl            | 0.07405078 |
# |    clip_fraction        | 0.515      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -19.7      |
# |    explained_variance   | 0.7210712  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0251    |
# |    n_updates            | 7030       |
# |    policy_gradient_loss | -0.0272    |
# |    std                  | 0.656      |
# |    value_loss           | 0.0508     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 161        |
# |    ep_rew_mean          | 180        |
# | time/                   |            |
# |    fps                  | 1140       |
# |    iterations           | 193        |
# |    time_elapsed         | 1386       |
# |    total_timesteps      | 5795136    |
# | train/                  |            |
# |    approx_kl            | 0.06858435 |
# |    clip_fraction        | 0.499      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -19.7      |
# |    explained_variance   | 0.7825349  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0134    |
# |    n_updates            | 7040       |
# |    policy_gradient_loss | -0.0236    |
# |    std                  | 0.654      |
# |    value_loss           | 0.0508     |
# ----------------------------------------
# Eval num_timesteps=5802816, episode_reward=247.34 +/- 115.35
# Episode length: 133.87 +/- 123.88
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 134         |
# |    mean_reward          | 247         |
# | time/                   |             |
# |    total_timesteps      | 5802816     |
# | train/                  |             |
# |    approx_kl            | 0.073167786 |
# |    clip_fraction        | 0.513       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -19.7       |
# |    explained_variance   | 0.7432778   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0175      |
# |    n_updates            | 7050        |
# |    policy_gradient_loss | -0.0276     |
# |    std                  | 0.653       |
# |    value_loss           | 0.0534      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 147      |
# |    ep_rew_mean     | 224      |
# | time/              |          |
# |    fps             | 1139     |
# |    iterations      | 194      |
# |    time_elapsed    | 1394     |
# |    total_timesteps | 5803328  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 145        |
# |    ep_rew_mean          | 222        |
# | time/                   |            |
# |    fps                  | 1140       |
# |    iterations           | 195        |
# |    time_elapsed         | 1400       |
# |    total_timesteps      | 5811520    |
# | train/                  |            |
# |    approx_kl            | 0.07466276 |
# |    clip_fraction        | 0.513      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -19.6      |
# |    explained_variance   | 0.7461127  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0399    |
# |    n_updates            | 7060       |
# |    policy_gradient_loss | -0.0299    |
# |    std                  | 0.651      |
# |    value_loss           | 0.0523     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 159         |
# |    ep_rew_mean          | 214         |
# | time/                   |             |
# |    fps                  | 1140        |
# |    iterations           | 196         |
# |    time_elapsed         | 1407        |
# |    total_timesteps      | 5819712     |
# | train/                  |             |
# |    approx_kl            | 0.073219426 |
# |    clip_fraction        | 0.515       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -19.6       |
# |    explained_variance   | 0.7284456   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0294     |
# |    n_updates            | 7070        |
# |    policy_gradient_loss | -0.0235     |
# |    std                  | 0.651       |
# |    value_loss           | 0.0507      |
# -----------------------------------------
